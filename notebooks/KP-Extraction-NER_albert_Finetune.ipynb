# %%
# Extended NER dataset with more examples and diverse entities
train_data = [{
    'text': 'The Hoover Dam is an engineering marvel. When Lake Mead, the reservoir behind the dam, is full, the dam withstands a\ngreat deal of force. However, water levels in the lake vary considerably as a result of droughts and varying water demands.\nLater in this chapter, we use definite integrals to calculate the force exerted on the dam when the reservoir is full and we\nexamine how changing water levels affect that force (see Example 6.28).\nHydrostatic force is only one of the many applications of definite integrals we explore in this chapter. From geometric\napplications such as surface area and volume, to physical applications such as mass and work, to growth and decay models,\ndefinite integrals are a powerful tool to help us understand and model the world around us.',
    'entities': [(4, 14, 'CONCEPT'), (21, 33, 'CONCEPT'), (131, 136, 'CONCEPT'), (271, 289, 'CONCEPT'),
                 (307, 312, 'CONCEPT'), (438, 455, 'CONCEPT'), (496, 514, 'CONCEPT'), (579, 602, 'CONCEPT'),
                 (666, 678, 'CONCEPT')]}, {
    'text': '9.1 The First Condition for Equilibrium        382\n9.2 The Second Condition for Equilibrium          384\n9.3 Stability        388\n9.4 Applications of Statics, Including Problem-Solving Strategies     393\n9.5 Simple Machines           396\n9.6 Forces and Torques in Muscles and Joints          400\nGlossary          407\nSection Summary            407\nConceptual Questions           408\nProblems & Exercises           409\nTest Prep for APÂ® Courses          414\nCHAPTER 10\nRotational Motion and Angular Momentum                                    417\nConnection for APÂ® Courses           417\n10.1 Angular Acceleration          419\n10.2 Kinematics of Rotational Motion         424\n10.3 Dynamics of Rotational Motion: Rotational Inertia      429\n10.4 Rotational Kinetic Energy: Work and Energy Revisited       434\n10.5 Angular Momentum and Its Conservation           44',
    'entities': [(28, 39, 'CONCEPT'), (109, 118, 'CONCEPT'), (150, 157, 'CONCEPT'), (242, 282, 'CONCEPT'),
                 (469, 486, 'CONCEPT'), (491, 507, 'CONCEPT'), (593, 613, 'CONCEPT'), (632, 663, 'CONCEPT'),
                 (681, 710, 'CONCEPT'), (745, 770, 'CONCEPT'), (772, 787, 'CONCEPT'), (813, 829, 'CONCEPT')]}, {
    'text': 'We have studied the general characteristics of functions, so now letâ€™s examine some specific classes of functions. We\nbegin by reviewing the basic properties of linear and quadratic functions, and then generalize to include higher-degree\npolynomials. By combining root functions with polynomials, we can define general algebraic functions and distinguish\nthem from the transcendental functions we examine later in this chapter. We finish the section with examples of piecewise-\ndefined functions and take a look at how to sketch the graph of a function that has been shifted, stretched, or reflected from\nits initial form.',
    'entities': [(161, 191, 'CONCEPT'), (224, 249, 'CONCEPT'), (264, 278, 'CONCEPT'), (284, 295, 'CONCEPT'),
                 (311, 338, 'CONCEPT'), (369, 393, 'CONCEPT')]}, {
    'text': 'Linear Functions and Slope The easiest type of function to consider is a linear function. Linear functions have the form f (x) = ax + b, where a and\n b are constants. In Figure 1.15, we see examples of linear functions when a is positive, negative, and zero. Note that if\n a > 0, the graph of the line rises as x increases. In other words, f (x) = ax + b is increasing on (??, ?). If a < 0,\nthe graph of the line falls as x increases. In this case, f (x) = ax + b is decreasing on (??, ?). If a = 0, the line is\nhorizontal.',
    'entities': [(0, 26, 'CONCEPT'), (73, 88, 'CONCEPT'), (90, 106, 'CONCEPT'), (202, 218, 'CONCEPT')]}, {
    'text': "stable definition of the kilogram. The kilogram is now defined in terms of the second, the meter, and Planck's\nconstant, h (a quantum mechanical value that relates a photon's energy to its frequency).\nElectric current and its accompanying unit, the ampere, will be introduced in Electric Current, Resistance, and Ohm's\nLaw when electricity and magnetism are covered. The initial modules in this textbook are concerned with\nmechanics, fluids, heat, and waves. In these subjects all pertinent physical quantities can be expressed in terms of\nthe fundamental units of length, mass, and time.\nMetric Prefixes\nSI units are part of the metric system. The metric system is convenient for scientific and engineering calculations\nbecause the units are categorized by factors of 10. Table 1.2 gives metric prefixes and symbols used to denote\nvarious factors of 10.",
    'entities': [(126, 144, 'CONCEPT'), (423, 432, 'CONCEPT'), (434, 440, 'CONCEPT'), (442, 446, 'CONCEPT'),
                 (452, 457, 'CONCEPT'), (696, 720, 'CONCEPT')]}, {
    'text': 'Science is based on observation and experimentâ€”that is, on measurements. Accuracy is how close a measurement\nis to the correct value for that measurement. For example, let us say that you are measuring the length of standard\ncomputer paper. The packaging in which you purchased the paper states that it is 11.0 inches long. You measure the\nlength of the paper three times and obtain the following measurements: 11.1 in., 11.2 in., and 10.9 in. These\nmeasurements are quite accurate because they are very close to the correct value of 11.0 inches. In contrast, if you\nhad obtained a measurement of 12 inches, your measurement would not be very accurate.\nThe precision of a measurement system refers to how close the agreement is between repeated measurements\n(which are repeated under the same conditions). Consider the example of the paper measurements. The precision\nof the measurements refers to the spread of the measured values. One way to analyze the precision of the\nmeasurements would be to determine the range, or difference, between the lowest and the highest measured\nvalues. In that case, the lowest value was 10.9 in. and the highest value was 11.2 in. Thus, the measured values',
    'entities': [(0, 7, 'CONCEPT'), (745, 757, 'CONCEPT')]}, {
    'text': 'Analytical methods of vector addition and subtraction employ geometry and simple trigonometry rather than the\nruler and protractor of graphical methods. Part of the graphical technique is retained, because vectors are still\nrepresented by arrows for easy visualization. However, analytical methods are more concise, accurate, and precise\nthan graphical methods, which are limited by the accuracy with which a drawing can be made. Analytical methods\nare limited only by the accuracy and precision with which physical quantities are known.\nResolving a Vector into Perpendicular Components\nAnalytical techniques and right triangles go hand-in-hand in physics because (among other things) motions along\nperpendicular directions are independent. We very often need to separate a vector into perpendicular components.\nFor example, given a vector like in Figure 3.24, we may wish to find which two perpendicular vectors, and, add to produce it.',
    'entities': [(22, 53, 'CONCEPT'), (61, 69, 'CONCEPT'), (81, 93, 'CONCEPT'), (165, 184, 'CONCEPT'),
                 (206, 213, 'CONCEPT'), (343, 360, 'CONCEPT'), (562, 586, 'CONCEPT'), (648, 655, 'CONCEPT'),
                 (891, 912, 'CONCEPT')]}, {
    'text': 'In the case of higher-degree polynomials, it may be more complicated to determine where the graph intersects the x -axis.\nIn some instances, it is possible to find the x -intercepts by factoring the polynomial to find its zeros. In other cases, it is\nimpossible to calculate the exact values of the x -intercepts. However, as we see later in the text, in cases such as this, we\ncan use analytical tools to approximate (to a very high degree) where the x -intercepts are located. Here we focus on the\ngraphs of polynomials for which we can calculate their zeros explicitly.',
    'entities': [(15, 40, 'CONCEPT'), (92, 108, 'CONCEPT'), (185, 209, 'CONCEPT'), (500, 521, 'CONCEPT')]}, {
    'text': 'Mathematical Models\nA large variety of real-world situations can be described using mathematical models. A mathematical model is a method of\nsimulating real-life situations with mathematical equations. Physicists, engineers, economists, and other researchers develop\nmodels by combining observation with quantitative data to develop equations, functions, graphs, and other mathematical\ntools to describe the behavior of various systems accurately. Models are useful because they help predict future outcomes.\nExamples of mathematical models include the study of population dynamics, investigations of weather patterns, and\npredictions of product sales.\nAs an example, letâ€™s consider a mathematical model that a company could use to describe its revenue for the sale of a\nparticular item. The amount of revenue R a company receives for the sale of n items sold at a price of p dollars per item\nis described by the equation R = p Â· n. The company is interested in how the sales change as the price of the item changes.\nSuppose the data in Table 1.6 show the number of units a company sells as a function of the price per item.',
    'entities': [(0, 19, 'CONCEPT'), (84, 103, 'CONCEPT'), (178, 200, 'CONCEPT'), (202, 212, 'CONCEPT'),
                 (214, 223, 'CONCEPT'), (225, 235, 'CONCEPT'), (304, 321, 'CONCEPT'), (333, 361, 'CONCEPT'),
                 (484, 507, 'CONCEPT'), (562, 581, 'CONCEPT'), (601, 617, 'CONCEPT'), (623, 651, 'CONCEPT')]}, {
    'text': 'We have seen the techniques for differentiating basic functions (x n, sin x, cos x, etc.) as well as sums, differences,\nproducts, quotients, and constant multiples of these functions. However, these techniques do not allow us to differentiate\ncompositions of functions, such as h(x) = sin??x 3?? or k(x) = 3x 2 + 1. In this section, we study the rule for finding the\nderivative of the composition of two or more functions. Deriving the Chain Rule\nWhen we have a function that is a composition of two or more functions, we could use all of the techniques we have already\nlearned to differentiate it. However, using all of those techniques to break down a function into simpler parts that we are\nable to differentiate can get cumbersome. Instead, we use the chain rule, which states that the derivative of a composite\nfunction is the derivative of the outer function evaluated at the inner function times the derivative of the inner function.\nTo put this rule into context, letâ€™s take a look at an example: h(x) = sin ??x 3??. We can think of the derivative of this function\nwith respect to x as the rate of change of sin??x 3?? relative to the change in x. Consequently, we want to know how sin??x 3??\nchanges as x changes. We can think of this event as a chain reaction: As x changes, x 3 changes, which leads to a change\nin sin ??x 3??. This chain reaction gives us hints as to what is involved in computing the derivative of sin??x 3??. First of all, a\nchange in x forcing a change in x 3 suggests that somehow the derivative of x 3 is involved. In addition, the change in x 3\nforcing a change in sin??x 3?? suggests that the derivative of sin(u) with respect to u, where u = x 3, is also part of the\nfinal derivative.',
    'entities': [(120, 129, 'CONCEPT'), (130, 139, 'CONCEPT'), (229, 268, 'CONCEPT'), (367, 377, 'CONCEPT'),
                 (436, 446, 'CONCEPT'), (756, 766, 'CONCEPT'), (790, 824, 'CONCEPT')]}, {
    'text': 'Calculating Projectile Motion: Hot Rock Projectile\nKilauea in Hawaii is the worldâ€™s most continuously active volcano. Very active volcanoes characteristically eject red-\nhot rocks and lava rather than smoke and ash. Suppose a large rock is ejected from the volcano with a speed of 25.0\nm/s and at an angle   above the horizontal, as shown in Figure 3.37. The rock strikes the side of the volcano at\nan altitude 20.0 m lower than its starting point. (a) Calculate the time it takes the rock to follow this path. (b) What\nare the magnitude and direction of the rockâ€™s velocity at impact?',
    'entities': [(12, 29, 'CONCEPT'), (272, 277, 'CONCEPT'), (528, 551, 'CONCEPT')]}, {
    'text': 'where  is the initial speed and   is the initial angle relative to the horizontal. The proof of this equation is left as\nan end-of-chapter problem (hints are given), but it does fit the major features of projectile range as described.\nWhen we speak of the range of a projectile on level ground, we assume that is very small compared with the\ncircumference of the Earth. If, however, the range is large, the Earth curves away below the projectile and\nacceleration of gravity changes direction along the path. The range is larger than predicted by the range equation\ngiven above because the projectile has farther to fall than it would on level ground. (See Figure 3.39.) If the initial\nspeed is great enough, the projectile goes into orbit. This possibility was recognized centuries before it could be\naccomplished. When an object is in orbit, the Earth curves away from underneath the object at the same rate as it\nfalls. The object thus falls continuously but never hits the surface. These and other aspects of orbital motion, such\nas the rotation of the Earth, will be covered analytically and in greater depth later in this text.\nOnce again we see that thinking about one topic, such as the range of a projectile, can lead us to others, such as the\nEarth orbits. In Addition of Velocities, we will examine the addition of velocities, which is another important aspect\nof two-dimensional kinematics and will also yield insights beyond the immediate topic.',
    'entities': [(22, 27, 'CONCEPT'), (204, 220, 'CONCEPT'), (450, 473, 'CONCEPT'), (1281, 1291, 'CONCEPT'),
                 (1390, 1400, 'CONCEPT')]}, {
    'text': 'The Fundamental Theorem of Calculus, Part 2, is perhaps the most important theorem in calculus. After tireless efforts\nby mathematicians for approximately 500 years, new techniques emerged that provided scientists with the necessary tools\nto explain many phenomena. Using calculus, astronomers could finally determine distances in space and map planetary\norbits. Everyday financial problems such as calculating marginal costs or predicting total profit could now be handled with\nsimplicity and accuracy. Engineers could calculate the bending strength of materials or the three-dimensional motion of\nobjects. Our view of the world was forever changed with calculus.\nAfter finding approximate areas by adding the areas of n rectangles, the application of this theorem is straightforward by\ncomparison. It almost seems too simple that the area of an entire curved region can be calculated by just evaluating an\nantiderivative at the first and last endpoints of an interval.',
    'entities': [(27, 35, 'CONCEPT'), (318, 336, 'CONCEPT'), (399, 425, 'CONCEPT'), (429, 452, 'CONCEPT'),
                 (534, 563, 'CONCEPT'), (571, 606, 'CONCEPT'), (908, 922, 'CONCEPT')]}, {
    'text': 'Integrals Resulting in Other Inverse Trigonometric Functions\nThere are six inverse trigonometric functions. However, only three integration formulas are noted in the rule on integration\nformulas resulting in inverse trigonometric functions because the remaining three are negative versions of the ones we use.\nThe only difference is whether the integrand is positive or negative. Rather than memorizing three more formulas, if the\nintegrand is negative, simply factor out ?1 and evaluate the integral using one of the formulas already provided. To close\nthis section, we examine one more formula: the integral resulting in the inverse tangent function.',
    'entities': [(0, 9, 'CONCEPT'), (37, 60, 'CONCEPT'), (174, 185, 'CONCEPT'), (208, 239, 'CONCEPT'),
                 (627, 651, 'CONCEPT')]}, {
    'text': 'The Hoover Dam is an engineering marvel. When Lake Mead, the reservoir behind the dam, is full, the dam withstands a\ngreat deal of force. However, water levels in the lake vary considerably as a result of droughts and varying water demands.\nLater in this chapter, we use definite integrals to calculate the force exerted on the dam when the reservoir is full and we\nexamine how changing water levels affect that force (see Example 6.28).\nHydrostatic force is only one of the many applications of definite integrals we explore in this chapter. From geometric\napplications such as surface area and volume, to physical applications such as mass and work, to growth and decay models,\ndefinite integrals are a powerful tool to help us understand and model the world around us.',
    'entities': [(4, 14, 'CONCEPT'), (117, 136, 'CONCEPT'), (271, 289, 'CONCEPT'), (412, 417, 'CONCEPT'),
                 (438, 455, 'CONCEPT'), (505, 514, 'CONCEPT'), (548, 570, 'CONCEPT'), (579, 602, 'CONCEPT'),
                 (637, 650, 'CONCEPT'), (655, 678, 'CONCEPT'), (680, 698, 'CONCEPT')]}, {
    'text': 'If your ears have ever popped on a plane flight or ached during a deep dive in a swimming pool, you have\nexperienced the effect of depth on pressure in a fluid. At the Earthâ€™s surface, the air pressure exerted on you is a\nresult of the weight of air above you. This pressure is reduced as you climb up in altitude and the weight of air above\nyou decreases. Under water, the pressure exerted on you increases with increasing depth. In this case, the pressure\nbeing exerted upon you is a result of both the weight of water above you and that of the atmosphere above you. You\nmay notice an air pressure change on an elevator ride that transports you many stories, but you need only dive a\nmeter or so below the surface of a pool to feel a pressure increase. The difference is that water is much denser than\nair, about 775 times as dense.',
    'entities': [(140, 159, 'CONCEPT'), (189, 201, 'CONCEPT')]}, {
    'text': 'This amount is significant, particularly for a 60.0-L tank. The effect is so striking because the gasoline and steel\nexpand quickly. The rate of change in thermal properties is discussed in Heat and Heat Transfer Methods.\nIf you try to cap the tank tightly to prevent overflow, you will find that it leaks anyway, either around the cap or by\nbursting the tank. Tightly constricting the expanding gas is equivalent to compressing it, and both liquids and solids\nresist being compressed with extremely large forces. To avoid rupturing rigid containers, these containers have air\ngaps, which allow them to expand and contract without stressing them.',
    'entities': [(133, 151, 'CONCEPT'), (500, 512, 'CONCEPT')]}, {
    'text': 'Thermal stress is created by thermal expansion or contraction (see Elasticity: Stress and Strain for a discussion of\nstress and strain). Thermal stress can be destructive, such as when expanding gasoline ruptures a tank. It can also\nbe useful, for example, when two parts are joined together by heating one in manufacturing, then slipping it over the\nother and allowing the combination to cool. Thermal stress can explain many phenomena, such as the weathering of\nrocks and pavement by the expansion of ice when it freezes.',
    'entities': [(0, 14, 'CONCEPT'), (29, 46, 'CONCEPT'), (50, 61, 'CONCEPT')]}, {
    'text': 'High-resolution measurements of atomic and molecular spectra show that the spectral lines are even more complex\nthan they first appear. In this section, we will see that this complexity has yielded important new information about\nelectrons and their orbits in atoms.\nIn order to explore the substructure of atoms (and knowing that magnetic fields affect moving charges), the Dutch\nphysicist Hendrik Lorentz (1853â€“1930) suggested that his student Pieter Zeeman (1865â€“1943) study how spectra\nmight be affected by magnetic fields. What they found became known as the Zeeman effect, which involved\nspectral lines being split into two or more separate emission lines by an external magnetic field, as shown in Figure\n30.47. For their discoveries, Zeeman and Lorentz shared the 1902 Nobel Prize in Physics.\nZeeman splitting is complex. Some lines split into three lines, some into five, and so on. But one general feature is\nthat the amount the split lines are separated is proportional to the applied field strength, indicating an interaction\nwith a moving charge. The splitting means that the quantized energy of an orbit is affected by an external magnetic\nfield, causing the orbit to have several discrete energies instead of one. Even without an external magnetic field,\nvery precise measurements showed that spectral lines are doublets (split into two), apparently by magnetic fields\nwithin the atom itself.',
    'entities': [(32, 52, 'CONCEPT'), (230, 239, 'CONCEPT'), (511, 526, 'CONCEPT'), (792, 799, 'CONCEPT'),
                 (988, 1010, 'CONCEPT'), (1089, 1117, 'CONCEPT'), (1145, 1159, 'CONCEPT')]}
]


# Define label to ID mapping
label2id = {
    "O": 0,
    "B-CONCEPT": 1,
    "I-CONCEPT": 2
}

id2label = {v: k for k, v in label2id.items()}

# %%
from torch.utils.data import Dataset, DataLoader
import torch
from torch.optim import AdamW
import numpy as np

# %%
class NERDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=512):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        text = item["text"]
        entities = item["entities"]

        # Create label sequence
        labels = ["O"] * len(text)
        for start, end, label in entities:
            labels[start] = f"B-{label}"
            for i in range(start + 1, end):
                labels[i] = f"I-{label}"

        # Tokenize text and align labels
        tokenized = self.tokenizer(
            text,
            padding="max_length",
            truncation=True,
            max_length=self.max_length,
            return_offsets_mapping=True
        )

        aligned_labels = [-100] * len(tokenized["input_ids"])  # -100 is ignored in loss calculation
        offset_mapping = tokenized["offset_mapping"]

        for idx, (start, end) in enumerate(offset_mapping):
            if start == end:  # Special tokens
                continue
            # Find the label for this token
            token_label = labels[start]
            aligned_labels[idx] = label2id[token_label]

        return {
            "input_ids": torch.tensor(tokenized["input_ids"]),
            "attention_mask": torch.tensor(tokenized["attention_mask"]),
            "labels": torch.tensor(aligned_labels)
        }

# %%
def train_model(model, train_dataloader, num_epochs=3, device="cuda"):
    optimizer = AdamW(model.parameters(), lr=2e-5)
    model.train()
    model.to(device)

    for epoch in range(num_epochs):
        total_loss = 0
        for batch in train_dataloader:
            optimizer.zero_grad()

            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels
            )

            loss = outputs.loss
            total_loss += loss.item()

            loss.backward()
            optimizer.step()

        avg_loss = total_loss / len(train_dataloader)
        print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {avg_loss:.4f}")

# %%
# Example of inference
def predict(text, model, tokenizer, device="cuda"):
    model.eval()
    tokenized = tokenizer(
        text,
        padding=True,
        truncation=True,
        return_offsets_mapping=True,
        return_tensors="pt"
    )

    with torch.no_grad():
        input_ids = tokenized["input_ids"].to(device)
        attention_mask = tokenized["attention_mask"].to(device)
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        predictions = torch.argmax(outputs.logits, dim=2)

    tokens = tokenizer.convert_ids_to_tokens(input_ids[0])
    token_predictions = [id2label[pred.item()] for pred in predictions[0]]

    entities = []
    current_entity = None

    for idx, (token, pred) in enumerate(zip(tokens, token_predictions)):
        if pred.startswith("B-"):
            if current_entity:
                entities.append(current_entity)
            current_entity = {"type": pred[2:], "start": idx, "text": token}
        elif pred.startswith("I-") and current_entity:
            current_entity["text"] += f" {token}"
        elif current_entity:
            entities.append(current_entity)
            current_entity = None

    if current_entity:
        entities.append(current_entity)

    return entities

# %%
from transformers import AlbertForTokenClassification
from transformers import AutoTokenizer

# Initialize tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("albert/albert-base-v2")
tokenizer.eos_token = tokenizer.pad_token

model = AlbertForTokenClassification.from_pretrained(
    "albert/albert-base-v2",
    num_labels=len(label2id),
    id2label=id2label,
    label2id=label2id
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
# Create dataset and dataloader
dataset = NERDataset(train_data, tokenizer)
train_dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
# Train the model
device = "cuda" if torch.cuda.is_available() else "cpu"
train_model(model, train_dataloader, num_epochs=25, device=device)
# Out:
# Epoch 1/25, Average Loss: 0.5013
# Epoch 2/25, Average Loss: 0.2772
# Epoch 3/25, Average Loss: 0.2072
# Epoch 4/25, Average Loss: 0.1770
# Epoch 5/25, Average Loss: 0.1486
# Epoch 6/25, Average Loss: 0.1076
# Epoch 7/25, Average Loss: 0.0992
# Epoch 8/25, Average Loss: 0.0949
# Epoch 9/25, Average Loss: 0.0839
# Epoch 10/25, Average Loss: 0.0565
# Epoch 11/25, Average Loss: 0.0428
# Epoch 12/25, Average Loss: 0.0305
# Epoch 13/25, Average Loss: 0.0304
# Epoch 14/25, Average Loss: 0.0278
# Epoch 15/25, Average Loss: 0.0215
# Epoch 16/25, Average Loss: 0.0207
# Epoch 17/25, Average Loss: 0.0195
# Epoch 18/25, Average Loss: 0.0276
# Epoch 19/25, Average Loss: 0.0152
# Epoch 20/25, Average Loss: 0.0129
# Epoch 21/25, Average Loss: 0.0177
# Epoch 22/25, Average Loss: 0.0133
# Epoch 23/25, Average Loss: 0.0129
# Epoch 24/25, Average Loss: 0.0120
# Epoch 25/25, Average Loss: 0.0157

# %%
# Save the model
model.save_pretrained("bert-ner-finetuned")
tokenizer.save_pretrained("bert-ner-finetuned")
# Out:
# ('bert-ner-finetuned/tokenizer_config.json',
#  'bert-ner-finetuned/special_tokens_map.json',
#  'bert-ner-finetuned/spiece.model',
#  'bert-ner-finetuned/added_tokens.json',
#  'bert-ner-finetuned/tokenizer.json')

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-ner-finetuned")
model = AlbertForTokenClassification.from_pretrained("bert-ner-finetuned")

# %%
text = """Transcendental Functions
Thus far, we have discussed algebraic functions. Some functions, however, cannot be described by basic algebraic
operations. These functions are known as transcendental functions because they are said to “transcend,” or go beyond,
algebra. The most common transcendental functions are trigonometric, exponential, and logarithmic functions. A
trigonometric function relates the ratios of two sides of a right triangle. They are sinx, cosx, tanx, cotx, secx, and cscx.
(We discuss trigonometric functions later in the chapter.) An exponential function is a function of the form f (x) = b x,
where the base b > 0, b ? 1. A logarithmic function is a function of the form f (x) = log b(x) for some constant
 b > 0, b ? 1, where log b (x) = y if and only if b y = x. (We also discuss exponential and logarithmic functions later in
the chapter."""

predictions = predict(text, model, tokenizer,device="cpu")
for i in predictions:
  print(i)

# %%
text = """This amount is significant, particularly for a 60.0-L tank. The effect is so striking because the gasoline and steel
expand quickly. The rate of change in thermal properties is discussed in Heat and Heat Transfer Methods.
If you try to cap the tank tightly to prevent overflow, you will find that it leaks anyway, either around the cap or by
bursting the tank. Tightly constricting the expanding gas is equivalent to compressing it, and both liquids and solids
resist being compressed with extremely large forces. To avoid rupturing rigid containers, these containers have air
gaps, which allow them to expand and contract without stressing them.
Thermal Stress
Thermal stress is created by thermal expansion or contraction (see Elasticity: Stress and Strain for a discussion of
stress and strain). Thermal stress can be destructive, such as when expanding gasoline ruptures a tank. It can also
be useful, for example, when two parts are joined together by heating one in manufacturing, then slipping it over the
other and allowing the combination to cool. Thermal stress can explain many phenomena, such as the weathering of
rocks and pavement by the expansion of ice when it freezes."""

predictions = predict(text, model, tokenizer,device="cpu")
for i in predictions:
  print(i)
# Out:
# {'type': 'CONCEPT', 'start': 29, 'text': '▁the ▁rate ▁of ▁change'}
# {'type': 'CONCEPT', 'start': 101, 'text': '▁large ▁forces'}
# {'type': 'CONCEPT', 'start': 132, 'text': '▁thermal'}
# {'type': 'CONCEPT', 'start': 139, 'text': '▁thermal ▁expansion'}
# {'type': 'CONCEPT', 'start': 238, 'text': '[SEP]'}

# %%
text = """Other ions of importance in biology that can reduce or screen Coulomb interactions are                            and        and       .
These ions are located both inside and outside of living cells. The movement of these ions through cell membranes
is crucial to the motion of nerve impulses through nerve axons.
Recent studies of electrostatics in biology seem to show that electric fields in cells can be extended over larger
distances, in spite of screening, by “microtubules” within the cell. These microtubules are hollow tubes composed
of proteins that guide the movement of chromosomes when cells divide, the motion of other organisms within the
cell, and provide mechanisms for motion of some cells (as motors).
FIGURE 18.33 This schematic shows water (          ) as a polar molecule. Unequal sharing of electrons between the oxygen (O) and hydrogen
(H) atoms leads to a net separation of positive and negative charge—forming a dipole. The symbols        and    indicate that the oxygen side
of the      molecule tends to be more negative, while the hydrogen ends tend to be more positive. This leads to an attraction of opposite
charges between molecules.
You are likely familiar with the role of electrical signals in nerve conduction and the importance of charges in cardiac
and related activity. Changes in electrical properties are also essential in core biological processes. Ernest Everett
Just, whose expertise in understanding and handling egg cells led to a number of critical experimental discoveries,
investigated the role of the cell membrane in reproductive fertilization. In one key experiment, Just established that
the egg membrane undergoes a depolarizing "wave of negativity" the moment it fuses with a sperm cell. This change
in charge is now known as the "fast block" that ensures that only one sperm cell fuses with an egg cell and is critical
for embryonic development."""

predictions = predict(text, model, tokenizer,device="cpu")
for i in predictions:
  print(i)
# Out:
# {'type': 'CONCEPT', 'start': 49, 'text': '▁motion ▁of ▁nerve ▁impulse s'}
# {'type': 'CONCEPT', 'start': 55, 'text': '▁nerve ▁a xon s'}
# {'type': 'CONCEPT', 'start': 63, 'text': '▁electro static s'}
# {'type': 'CONCEPT', 'start': 246, 'text': '▁nerve ▁conduct ion'}
# {'type': 'CONCEPT', 'start': 255, 'text': '▁cardiac ▁and'}
# {'type': 'CONCEPT', 'start': 301, 'text': '▁reproductive ▁fer til ization'}
# {'type': 'CONCEPT', 'start': 380, 'text': '[SEP]'}

# %%
tokenizer.tokenize(text)
# Out:
# ['▁other',
#  '▁',
#  'ions',
#  '▁of',
#  '▁importance',
#  '▁in',
#  '▁biology',
#  '▁that',
#  '▁can',
#  '▁reduce',
#  '▁or',
#  '▁screen',
#  '▁coul',
#  'o',
#  'mb',
#  '▁interactions',
#  '▁are',
#  '▁and',
#  '▁and',
#  '▁',
#  '.',
#  '▁these',
#  '▁',
#  'ions',
#  '▁are',
#  '▁located',
#  '▁both',
#  '▁inside',
#  '▁and',
#  '▁outside',
#  '▁of',
#  '▁living',
#  '▁cells',
#  '.',
#  '▁the',
#  '▁movement',
#  '▁of',
#  '▁these',
#  '▁',
#  'ions',
#  '▁through',
#  '▁cell',
#  '▁membrane',
#  's',
#  '▁is',
#  '▁crucial',
#  '▁to',
#  '▁the',
#  '▁motion',
#  '▁of',
#  '▁nerve',
#  '▁impulse',
#  's',
#  '▁through',
#  '▁nerve',
#  '▁a',
#  'xon',
#  's',
#  '.',
#  '▁recent',
#  '▁studies',
#  '▁of',
#  '▁electro',
#  'static',
#  's',
#  '▁in',
#  '▁biology',
#  '▁seem',
#  '▁to',
#  '▁show',
#  '▁that',
#  '▁electric',
#  '▁fields',
#  '▁in',
#  '▁cells',
#  '▁can',
#  '▁be',
#  '▁extended',
#  '▁over',
#  '▁larger',
#  '▁distances',
#  ',',
#  '▁in',
#  '▁spite',
# ...

# %%
text = """The numbers are quite large, so the result might surprise you. Experiments such as this were performed in the early
1960s to test the limits of human endurance and the setup designed to protect human subjects in jet fighter
emergency ejections. Speeds of 1000 km/h were obtained, with accelerations of 45 's. (Recall that , the
acceleration due to gravity, is             . When we say that an acceleration is 45 's, it is   ×           , which is
approximately              .) While living subjects are not used any more, land speeds of 10,000 km/h have been
obtained with rocket sleds. In this example, as in the preceding one, the system of interest is obvious. We will see in
later examples that choosing the system of interest is crucial—and the choice is not always obvious.
Newton’s second law of motion is more than a definition; it is a relationship among acceleration, force, and mass. It
can help us make predictions. Each of those physical quantities can be defined independently, so the second law
tells us something basic and universal about nature. The next section introduces the third and final law of motion.
4.4 Newton’s Third Law of Motion: Symmetry in Forces"""

predictions = predict(text, model, tokenizer,device="cpu")
for i in predictions:
  print(i)
# Out:
# {'type': 'CONCEPT', 'start': 30, 'text': '▁human ▁endurance'}
# {'type': 'CONCEPT', 'start': 41, 'text': '▁jet'}
# {'type': 'CONCEPT', 'start': 57, 'text': '▁acceleration'}
# {'type': 'CONCEPT', 'start': 76, 'text': '▁gravity'}
# {'type': 'CONCEPT', 'start': 114, 'text': '▁land ▁speeds'}
# {'type': 'CONCEPT', 'start': 187, 'text': '▁acceleration'}
# {'type': 'CONCEPT', 'start': 189, 'text': '▁force'}
# {'type': 'CONCEPT', 'start': 192, 'text': '▁mass'}
# {'type': 'CONCEPT', 'start': 199, 'text': '▁prediction'}
# {'type': 'CONCEPT', 'start': 248, 'text': '▁symmetry ▁in ▁forces'}
# {'type': 'CONCEPT', 'start': 251, 'text': '[SEP]'}
